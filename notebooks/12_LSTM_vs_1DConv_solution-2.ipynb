# %% [markdown]
# ## Prediction of time series with different neural networks architectures
#
# In this notebook we will use different network architectures to predict the next steps for a time series. We compare 1D convolutional networks with and without dilation rate and LSTMs. We predict the time series for longer times than we trained them on and compare the results of the different architectures. The goal is to capture the long term dependencies of the time series.

# %%
# load required libraries:
import numpy as np
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline

import keras 
from keras.models import Sequential
from keras.layers import Dense, Lambda, Convolution1D,LSTM, SimpleRNN
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Simulate some data
#
# In the next cell we generate train and validation data. We multiply a fast sine wave with a slower sine wave and add a bit random noise. The goal is to learn from the past of time series and predict the next 10 steps and later even more than "only"  10 steps.

# %%
np.random.seed(1) # Fixing the seed, so data generation is always the same
seq_length = 128  # Sequence length used for training
look_ahead =  10  # The number of data points the model should predict 


def gen_data(size=1000, noise=0.1,seq_length=128,look_ahead=10): # We create 1000 observations of the process
  s = seq_length + look_ahead
  d = np.zeros((size, s,1))
  for i in range(size):
    start = np.random.uniform(0, 2*np.pi) # Random start point
    d[i,:,0] = np.sin(start + np.linspace(0, 20*np.pi, s)) * np.sin(start + np.linspace(0, np.pi, s)) + np.random.normal(0,noise,s)
  return d[:,0:seq_length], d[:,seq_length:s]


X,Y = gen_data()
for i in range(1):
  plt.figure(num=None, figsize=(13,5))  
  plt.plot(range(0, seq_length),X[i,:,0],'b-')
  plt.plot(range(seq_length, seq_length + look_ahead),Y[i,:,0],'b-',color='orange')

plt.show()
print('The training data X is the blue line and we want to forecast the next 10 steps Y, the orange line.')
# Out:
# The training data X is the blue line and we want to forecast the next 10 steps Y, the orange line.

# %%
plt.figure(figsize=(13,5))
plt.plot(range(0,seq_length), np.gradient(X[0,:,0]), label='$ dx/dt$' )
plt.plot(range(0,seq_length), np.gradient(np.gradient(X[0,:,0])), label='$ d^{2}x/dt^{2}$' )
plt.legend()

# %%
# process:fast sine wave * slow sine wave + random noise
start = np.random.uniform(0, 2*np.pi) # Random start point
s=128+10
plt.figure(figsize=(13,5))  
plt.plot(np.sin(start + np.linspace(0, 20*np.pi, s)))
plt.show()
plt.figure(figsize=(13,5))  
plt.plot(np.sin(start + np.linspace(0, np.pi, s)))
plt.show()
plt.figure(figsize=(13,5))  
plt.plot(np.sin(start + np.linspace(0, 20*np.pi, s))*np.sin(start + np.linspace(0, np.pi, s)))
plt.show()
plt.figure(figsize=(13,5))  
plt.plot(np.sin(start + np.linspace(0, 20*np.pi, s))*np.sin(start + np.linspace(0, np.pi, s))+np.random.normal(0,0.1,s))
plt.show()

# %%
print(X.shape)
print(Y.shape)
# Out:
# (1000, 128, 1)
# (1000, 10, 1)

# %% [markdown]
# ### 1D Convolution without dilation rate

# %% [markdown]
# Here we define a Neural network with 1D convolutions and "causal" padding, in a later step we will also use a dilation rate.

# %%
def slice(x, slice_length):
    return x[:,-slice_length:,:]
  
model_1Dconv = Sequential()
ks = 5
model_1Dconv.add(Convolution1D(filters=32, kernel_size=ks, padding='causal', input_shape=(128, 1)))
model_1Dconv.add(Convolution1D(filters=32, kernel_size=ks, padding='causal'))
model_1Dconv.add(Convolution1D(filters=32, kernel_size=ks, padding='causal'))
model_1Dconv.add(Convolution1D(filters=32, kernel_size=ks, padding='causal'))
model_1Dconv.add(Dense(1))
model_1Dconv.add(Lambda(slice, arguments={'slice_length':look_ahead}))

model_1Dconv.compile(optimizer='adam', loss='mean_squared_error')
model_1Dconv.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 128, 32)           192
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 128, 32)           5152
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 128, 32)           5152
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 128, 32)           5152
# _________________________________________________________________
# dense_1 (Dense)              (None, 128, 1)            33
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 10, 1)             0
# =================================================================
# Total params: 15,681
# Trainable params: 15,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model_1Dconv.fit(X[0:800], Y[0:800],
                    epochs=100,
                    batch_size=128,
                    validation_data=(X[800:1000],Y[800:1000]),
                    verbose=1)
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.1135 - val_loss: 0.0369
# Epoch 2/100
# 800/800 [==============================] - 1s 672us/step - loss: 0.0463 - val_loss: 0.0408
# Epoch 3/100
# 800/800 [==============================] - 1s 641us/step - loss: 0.0379 - val_loss: 0.0383
# Epoch 4/100
# 800/800 [==============================] - 1s 664us/step - loss: 0.0347 - val_loss: 0.0316
# Epoch 5/100
# 800/800 [==============================] - 1s 645us/step - loss: 0.0332 - val_loss: 0.0288
# Epoch 6/100
# 800/800 [==============================] - 1s 654us/step - loss: 0.0313 - val_loss: 0.0268
# Epoch 7/100
# 800/800 [==============================] - 1s 632us/step - loss: 0.0295 - val_loss: 0.0258
# Epoch 8/100
# 800/800 [==============================] - 1s 631us/step - loss: 0.0282 - val_loss: 0.0247
# Epoch 9/100
# 800/800 [==============================] - 0s 624us/step - loss: 0.0271 - val_loss: 0.0248
# Epoch 10/100
# 800/800 [==============================] - 1s 637us/step - loss: 0.0266 - val_loss: 0.0235
# Epoch 11/100
# 800/800 [==============================] - 1s 646us/step - loss: 0.0258 - val_loss: 0.0233
# Epoch 12/100
# 800/800 [==============================] - 0s 624us/step - loss: 0.0254 - val_loss: 0.0233
# Epoch 13/100
# 800/800 [==============================] - 1s 631us/step - loss: 0.0254 - val_loss: 0.0237
# Epoch 14/100
# 800/800 [==============================] - 0s 620us/step - loss: 0.0256 - val_loss: 0.0236
# Epoch 15/100
# 800/800 [==============================] - 0s 599us/step - loss: 0.0254 - val_loss: 0.0239
# Epoch 16/100
# 800/800 [==============================] - 1s 648us/step - loss: 0.0254 - val_loss: 0.0234
# Epoch 17/100
# 800/800 [==============================] - 1s 635us/step - loss: 0.0252 - val_loss: 0.0233
# Epoch 18/100
# 800/800 [==============================] - 1s 630us/step - loss: 0.0253 - val_loss: 0.0234
# Epoch 19/100
# 800/800 [==============================] - 1s 689us/step - loss: 0.0255 - val_loss: 0.0240
# Epoch 20/100
# 800/800 [==============================] - 1s 697us/step - loss: 0.0256 - val_loss: 0.0239
# Epoch 21/100
# 800/800 [==============================] - 1s 631us/step - loss: 0.0253 - val_loss: 0.0234
# Epoch 22/100
# 800/800 [==============================] - 1s 808us/step - loss: 0.0250 - val_loss: 0.0229
# Epoch 23/100
# 800/800 [==============================] - 0s 618us/step - loss: 0.0248 - val_loss: 0.0228
# Epoch 24/100
# 800/800 [==============================] - 1s 669us/step - loss: 0.0247 - val_loss: 0.0230
# Epoch 25/100
# 800/800 [==============================] - 0s 600us/step - loss: 0.0248 - val_loss: 0.0229
# Epoch 26/100
# 800/800 [==============================] - 0s 590us/step - loss: 0.0250 - val_loss: 0.0241
# Epoch 27/100
# 800/800 [==============================] - 1s 788us/step - loss: 0.0250 - val_loss: 0.0241
# Epoch 28/100
# 800/800 [==============================] - 1s 716us/step - loss: 0.0254 - val_loss: 0.0253
# Epoch 29/100
# 800/800 [==============================] - 1s 648us/step - loss: 0.0260 - val_loss: 0.0235
# Epoch 30/100
# 800/800 [==============================] - 0s 620us/step - loss: 0.0251 - val_loss: 0.0229
# Epoch 31/100
# 800/800 [==============================] - 1s 634us/step - loss: 0.0248 - val_loss: 0.0233
# Epoch 32/100
# 800/800 [==============================] - 0s 614us/step - loss: 0.0249 - val_loss: 0.0228
# Epoch 33/100
# 800/800 [==============================] - 0s 616us/step - loss: 0.0248 - val_loss: 0.0235
# Epoch 34/100
# 800/800 [==============================] - 1s 667us/step - loss: 0.0253 - val_loss: 0.0232
# Epoch 35/100
# 800/800 [==============================] - 1s 635us/step - loss: 0.0251 - val_loss: 0.0227
# Epoch 36/100
# 800/800 [==============================] - 0s 613us/step - loss: 0.0248 - val_loss: 0.0224
# Epoch 37/100
# 800/800 [==============================] - 1s 671us/step - loss: 0.0248 - val_loss: 0.0228
# Epoch 38/100
# 800/800 [==============================] - 0s 619us/step - loss: 0.0246 - val_loss: 0.0237
# Epoch 39/100
# 800/800 [==============================] - 1s 650us/step - loss: 0.0246 - val_loss: 0.0236
# Epoch 40/100
# 800/800 [==============================] - 1s 711us/step - loss: 0.0249 - val_loss: 0.0227
# Epoch 41/100
# 800/800 [==============================] - 1s 667us/step - loss: 0.0242 - val_loss: 0.0233
# Epoch 42/100
# 800/800 [==============================] - 1s 660us/step - loss: 0.0247 - val_loss: 0.0225
# Epoch 43/100
# 800/800 [==============================] - 1s 637us/step - loss: 0.0240 - val_loss: 0.0222
# Epoch 44/100
# 800/800 [==============================] - 1s 660us/step - loss: 0.0241 - val_loss: 0.0224
# Epoch 45/100
# 800/800 [==============================] - 1s 674us/step - loss: 0.0241 - val_loss: 0.0222
# Epoch 46/100
# 800/800 [==============================] - 0s 611us/step - loss: 0.0240 - val_loss: 0.0221
# Epoch 47/100
# 800/800 [==============================] - 1s 632us/step - loss: 0.0240 - val_loss: 0.0225
# Epoch 48/100
# 800/800 [==============================] - 1s 629us/step - loss: 0.0244 - val_loss: 0.0230
# Epoch 49/100
# 800/800 [==============================] - 1s 635us/step - loss: 0.0254 - val_loss: 0.0228
# Epoch 50/100
# 800/800 [==============================] - 1s 630us/step - loss: 0.0256 - val_loss: 0.0221
# Epoch 51/100
# 800/800 [==============================] - 1s 629us/step - loss: 0.0244 - val_loss: 0.0232
# Epoch 52/100
# 800/800 [==============================] - 1s 657us/step - loss: 0.0243 - val_loss: 0.0233
# Epoch 53/100
# 800/800 [==============================] - 1s 669us/step - loss: 0.0239 - val_loss: 0.0222
# Epoch 54/100
# 800/800 [==============================] - 1s 663us/step - loss: 0.0238 - val_loss: 0.0220
# Epoch 55/100
# 800/800 [==============================] - 1s 640us/step - loss: 0.0239 - val_loss: 0.0241
# Epoch 56/100
# 800/800 [==============================] - 1s 644us/step - loss: 0.0245 - val_loss: 0.0241
# Epoch 57/100
# 800/800 [==============================] - 1s 652us/step - loss: 0.0245 - val_loss: 0.0243
# Epoch 58/100
# 800/800 [==============================] - 1s 653us/step - loss: 0.0246 - val_loss: 0.0238
# Epoch 59/100
# 800/800 [==============================] - 1s 649us/step - loss: 0.0243 - val_loss: 0.0238
# Epoch 60/100
# 800/800 [==============================] - 1s 632us/step - loss: 0.0243 - val_loss: 0.0220
# Epoch 61/100
# 800/800 [==============================] - 0s 607us/step - loss: 0.0240 - val_loss: 0.0221
# Epoch 62/100
# 800/800 [==============================] - 1s 635us/step - loss: 0.0238 - val_loss: 0.0219
# Epoch 63/100
# 800/800 [==============================] - 1s 652us/step - loss: 0.0239 - val_loss: 0.0218
# Epoch 64/100
# 800/800 [==============================] - 1s 659us/step - loss: 0.0238 - val_loss: 0.0218
# Epoch 65/100
# 800/800 [==============================] - 1s 644us/step - loss: 0.0237 - val_loss: 0.0224
# Epoch 66/100
# 800/800 [==============================] - 0s 624us/step - loss: 0.0236 - val_loss: 0.0224
# Epoch 67/100
# 800/800 [==============================] - 0s 622us/step - loss: 0.0237 - val_loss: 0.0218
# Epoch 68/100
# 800/800 [==============================] - 0s 615us/step - loss: 0.0238 - val_loss: 0.0226
# Epoch 69/100
# 800/800 [==============================] - 1s 653us/step - loss: 0.0244 - val_loss: 0.0220
# Epoch 70/100
# 800/800 [==============================] - 1s 636us/step - loss: 0.0241 - val_loss: 0.0221
# Epoch 71/100
# 800/800 [==============================] - 1s 634us/step - loss: 0.0236 - val_loss: 0.0220
# Epoch 72/100
# 800/800 [==============================] - 1s 629us/step - loss: 0.0237 - val_loss: 0.0220
# Epoch 73/100
# 800/800 [==============================] - 1s 629us/step - loss: 0.0236 - val_loss: 0.0221
# Epoch 74/100
# 800/800 [==============================] - 1s 653us/step - loss: 0.0237 - val_loss: 0.0219
# Epoch 75/100
# 800/800 [==============================] - 0s 623us/step - loss: 0.0237 - val_loss: 0.0220
# Epoch 76/100
# 800/800 [==============================] - 0s 623us/step - loss: 0.0238 - val_loss: 0.0220
# Epoch 77/100
# 800/800 [==============================] - 1s 642us/step - loss: 0.0240 - val_loss: 0.0225
# Epoch 78/100
# 800/800 [==============================] - 1s 644us/step - loss: 0.0240 - val_loss: 0.0226
# Epoch 79/100
# 800/800 [==============================] - 0s 624us/step - loss: 0.0238 - val_loss: 0.0220
# Epoch 80/100
# 800/800 [==============================] - 1s 644us/step - loss: 0.0236 - val_loss: 0.0237
# Epoch 81/100
# 800/800 [==============================] - 0s 612us/step - loss: 0.0243 - val_loss: 0.0224
# Epoch 82/100
# 800/800 [==============================] - 1s 644us/step - loss: 0.0237 - val_loss: 0.0223
# Epoch 83/100
# 800/800 [==============================] - 0s 614us/step - loss: 0.0240 - val_loss: 0.0218
# Epoch 84/100
# 800/800 [==============================] - 0s 621us/step - loss: 0.0237 - val_loss: 0.0221
# Epoch 85/100
# 800/800 [==============================] - 0s 591us/step - loss: 0.0238 - val_loss: 0.0225
# Epoch 86/100
# 800/800 [==============================] - 1s 632us/step - loss: 0.0244 - val_loss: 0.0220
# Epoch 87/100
# 800/800 [==============================] - 1s 630us/step - loss: 0.0243 - val_loss: 0.0224
# Epoch 88/100
# 800/800 [==============================] - 0s 597us/step - loss: 0.0244 - val_loss: 0.0220
# Epoch 89/100
# 800/800 [==============================] - 1s 629us/step - loss: 0.0240 - val_loss: 0.0218
# Epoch 90/100
# 800/800 [==============================] - 0s 607us/step - loss: 0.0239 - val_loss: 0.0217
# Epoch 91/100
# 800/800 [==============================] - 0s 584us/step - loss: 0.0237 - val_loss: 0.0222
# Epoch 92/100
# 800/800 [==============================] - 0s 602us/step - loss: 0.0236 - val_loss: 0.0218
# Epoch 93/100
# 800/800 [==============================] - 0s 619us/step - loss: 0.0235 - val_loss: 0.0229
# Epoch 94/100
# 800/800 [==============================] - 0s 601us/step - loss: 0.0243 - val_loss: 0.0218
# Epoch 95/100
# 800/800 [==============================] - 0s 617us/step - loss: 0.0235 - val_loss: 0.0218
# Epoch 96/100
# 800/800 [==============================] - 1s 634us/step - loss: 0.0236 - val_loss: 0.0220
# Epoch 97/100
# 800/800 [==============================] - 0s 623us/step - loss: 0.0239 - val_loss: 0.0227
# Epoch 98/100
# 800/800 [==============================] - 0s 624us/step - loss: 0.0240 - val_loss: 0.0220
# Epoch 99/100
# 800/800 [==============================] - 1s 677us/step - loss: 0.0242 - val_loss: 0.0228
# Epoch 100/100
# 800/800 [==============================] - 0s 575us/step - loss: 0.0243 - val_loss: 0.0224

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid']);

# %% [markdown]
# Now we want to use the trained model to predict for the next 10 steps, remember that is what the model was trained on.
# In addition,  we want to predict for longer than just 10 steps, we will  just predict the next 10 steps and take the predictions as new "true" observations and feed these values into the model, when we do that we can predict for any length we want. In the next cell we will predict the next 10 and 80 steps.

# %%
### predict for 10 steps
i=950
steps = 1
pred = np.empty(0)
data = X[i:i+1]
model = model_1Dconv

for j in range(0,steps):
  res = model.predict(data)[0].reshape(10)
  pred=np.append(pred,res)
    
plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)

### predict for 80 steps
i=950
steps = 8
pred = np.empty(0)
data = X[i:i+1]
model = model_1Dconv

for j in range(0,steps):
  res = model.predict(data)[0].reshape(10)
  pred=np.append(pred,res)

plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)

# %% [markdown]
# ### 1D Convolution with dilation rate

# %% [markdown]
# Here we define a Neural network with 1D convolutions and "causal" padding, this time with dilation rate, so we are able to look back longer in time.

# %%
model_1Dconv_w_d = Sequential()
ks = 5
model_1Dconv_w_d.add(Convolution1D(filters=32, kernel_size=ks, padding='causal', dilation_rate=1, input_shape=(128, 1)))
model_1Dconv_w_d.add(Convolution1D(filters=32, kernel_size=ks, padding='causal', dilation_rate=2))
model_1Dconv_w_d.add(Convolution1D(filters=32, kernel_size=ks, padding='causal', dilation_rate=4))
model_1Dconv_w_d.add(Convolution1D(filters=32, kernel_size=ks, padding='causal', dilation_rate=8))
model_1Dconv_w_d.add(Dense(1))
model_1Dconv_w_d.add(Lambda(slice, arguments={'slice_length':look_ahead}))

model_1Dconv_w_d.compile(optimizer='adam', loss='mean_squared_error')
model_1Dconv_w_d.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 128, 32)           192
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 128, 32)           5152
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 128, 32)           5152
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 128, 32)           5152
# _________________________________________________________________
# dense_2 (Dense)              (None, 128, 1)            33
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 10, 1)             0
# =================================================================
# Total params: 15,681
# Trainable params: 15,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model_1Dconv_w_d.fit(X[0:800], Y[0:800],
                    epochs=100,
                    batch_size=128,
                    validation_data=(X[800:1000],Y[800:1000]),
                    verbose=1)
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.1679 - val_loss: 0.0490
# Epoch 2/100
# 800/800 [==============================] - 1s 820us/step - loss: 0.0446 - val_loss: 0.0292
# Epoch 3/100
# 800/800 [==============================] - 1s 835us/step - loss: 0.0248 - val_loss: 0.0174
# Epoch 4/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.0164 - val_loss: 0.0162
# Epoch 5/100
# 800/800 [==============================] - 1s 845us/step - loss: 0.0162 - val_loss: 0.0129
# Epoch 6/100
# 800/800 [==============================] - 1s 851us/step - loss: 0.0138 - val_loss: 0.0136
# Epoch 7/100
# 800/800 [==============================] - 1s 835us/step - loss: 0.0133 - val_loss: 0.0120
# Epoch 8/100
# 800/800 [==============================] - 1s 843us/step - loss: 0.0129 - val_loss: 0.0118
# Epoch 9/100
# 800/800 [==============================] - 1s 953us/step - loss: 0.0127 - val_loss: 0.0119
# Epoch 10/100
# 800/800 [==============================] - 1s 889us/step - loss: 0.0125 - val_loss: 0.0116
# Epoch 11/100
# 800/800 [==============================] - 1s 795us/step - loss: 0.0126 - val_loss: 0.0116
# Epoch 12/100
# 800/800 [==============================] - 1s 804us/step - loss: 0.0123 - val_loss: 0.0116
# Epoch 13/100
# 800/800 [==============================] - 1s 798us/step - loss: 0.0123 - val_loss: 0.0116
# Epoch 14/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.0122 - val_loss: 0.0116
# Epoch 15/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.0122 - val_loss: 0.0112
# Epoch 16/100
# 800/800 [==============================] - 1s 855us/step - loss: 0.0121 - val_loss: 0.0112
# Epoch 17/100
# 800/800 [==============================] - 1s 929us/step - loss: 0.0121 - val_loss: 0.0111
# Epoch 18/100
# 800/800 [==============================] - 1s 833us/step - loss: 0.0120 - val_loss: 0.0112
# Epoch 19/100
# 800/800 [==============================] - 1s 818us/step - loss: 0.0120 - val_loss: 0.0111
# Epoch 20/100
# 800/800 [==============================] - 1s 815us/step - loss: 0.0119 - val_loss: 0.0110
# Epoch 21/100
# 800/800 [==============================] - 1s 827us/step - loss: 0.0119 - val_loss: 0.0110
# Epoch 22/100
# 800/800 [==============================] - 1s 815us/step - loss: 0.0119 - val_loss: 0.0111
# Epoch 23/100
# 800/800 [==============================] - 1s 813us/step - loss: 0.0120 - val_loss: 0.0111
# Epoch 24/100
# 800/800 [==============================] - 1s 815us/step - loss: 0.0120 - val_loss: 0.0109
# Epoch 25/100
# 800/800 [==============================] - 1s 837us/step - loss: 0.0120 - val_loss: 0.0110
# Epoch 26/100
# 800/800 [==============================] - 1s 818us/step - loss: 0.0118 - val_loss: 0.0111
# Epoch 27/100
# 800/800 [==============================] - 1s 791us/step - loss: 0.0119 - val_loss: 0.0110
# Epoch 28/100
# 800/800 [==============================] - 1s 795us/step - loss: 0.0120 - val_loss: 0.0111
# Epoch 29/100
# 800/800 [==============================] - 1s 782us/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 30/100
# 800/800 [==============================] - 1s 785us/step - loss: 0.0119 - val_loss: 0.0110
# Epoch 31/100
# 800/800 [==============================] - 1s 817us/step - loss: 0.0118 - val_loss: 0.0111
# Epoch 32/100
# 800/800 [==============================] - 1s 780us/step - loss: 0.0118 - val_loss: 0.0111
# Epoch 33/100
# 800/800 [==============================] - 1s 788us/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 34/100
# 800/800 [==============================] - 1s 769us/step - loss: 0.0118 - val_loss: 0.0111
# Epoch 35/100
# 800/800 [==============================] - 1s 791us/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 36/100
# 800/800 [==============================] - 1s 766us/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 37/100
# 800/800 [==============================] - 1s 791us/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 38/100
# 800/800 [==============================] - 1s 798us/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 39/100
# 800/800 [==============================] - 1s 781us/step - loss: 0.0122 - val_loss: 0.0108
# Epoch 40/100
# 800/800 [==============================] - 1s 789us/step - loss: 0.0118 - val_loss: 0.0113
# Epoch 41/100
# 800/800 [==============================] - 1s 800us/step - loss: 0.0121 - val_loss: 0.0109
# Epoch 42/100
# 800/800 [==============================] - 1s 813us/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 43/100
# 800/800 [==============================] - 1s 823us/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 44/100
# 800/800 [==============================] - 1s 821us/step - loss: 0.0118 - val_loss: 0.0111
# Epoch 45/100
# 800/800 [==============================] - 1s 837us/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 46/100
# 800/800 [==============================] - 1s 843us/step - loss: 0.0120 - val_loss: 0.0111
# Epoch 47/100
# 800/800 [==============================] - 1s 820us/step - loss: 0.0119 - val_loss: 0.0110
# Epoch 48/100
# 800/800 [==============================] - 1s 832us/step - loss: 0.0119 - val_loss: 0.0108
# Epoch 49/100
# 800/800 [==============================] - 1s 847us/step - loss: 0.0119 - val_loss: 0.0114
# Epoch 50/100
# 800/800 [==============================] - 1s 849us/step - loss: 0.0120 - val_loss: 0.0109
# Epoch 51/100
# 800/800 [==============================] - 1s 833us/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 52/100
# 800/800 [==============================] - 1s 865us/step - loss: 0.0119 - val_loss: 0.0112
# Epoch 53/100
# 800/800 [==============================] - 1s 808us/step - loss: 0.0119 - val_loss: 0.0114
# Epoch 54/100
# 800/800 [==============================] - 1s 826us/step - loss: 0.0125 - val_loss: 0.0129
# Epoch 55/100
# 800/800 [==============================] - 1s 826us/step - loss: 0.0124 - val_loss: 0.0110
# Epoch 56/100
# 800/800 [==============================] - 1s 844us/step - loss: 0.0118 - val_loss: 0.0120
# Epoch 57/100
# 800/800 [==============================] - 1s 820us/step - loss: 0.0121 - val_loss: 0.0113
# Epoch 58/100
# 800/800 [==============================] - 1s 838us/step - loss: 0.0118 - val_loss: 0.0107
# Epoch 59/100
# 800/800 [==============================] - 1s 840us/step - loss: 0.0118 - val_loss: 0.0119
# Epoch 60/100
# 800/800 [==============================] - 1s 812us/step - loss: 0.0123 - val_loss: 0.0112
# Epoch 61/100
# 800/800 [==============================] - 1s 817us/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 62/100
# 800/800 [==============================] - 1s 804us/step - loss: 0.0118 - val_loss: 0.0110
# Epoch 63/100
# 800/800 [==============================] - 1s 831us/step - loss: 0.0119 - val_loss: 0.0112
# Epoch 64/100
# 800/800 [==============================] - 1s 785us/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 65/100
# 800/800 [==============================] - 1s 772us/step - loss: 0.0118 - val_loss: 0.0108
# Epoch 66/100
# 800/800 [==============================] - 1s 795us/step - loss: 0.0117 - val_loss: 0.0108
# Epoch 67/100
# 800/800 [==============================] - 1s 810us/step - loss: 0.0118 - val_loss: 0.0112
# Epoch 68/100
# 800/800 [==============================] - 1s 802us/step - loss: 0.0118 - val_loss: 0.0115
# Epoch 69/100
# 800/800 [==============================] - 1s 779us/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 70/100
# 800/800 [==============================] - 1s 808us/step - loss: 0.0121 - val_loss: 0.0111
# Epoch 71/100
# 800/800 [==============================] - 1s 772us/step - loss: 0.0118 - val_loss: 0.0110
# Epoch 72/100
# 800/800 [==============================] - 1s 790us/step - loss: 0.0117 - val_loss: 0.0107
# Epoch 73/100
# 800/800 [==============================] - 1s 796us/step - loss: 0.0117 - val_loss: 0.0110
# Epoch 74/100
# 800/800 [==============================] - 1s 782us/step - loss: 0.0117 - val_loss: 0.0108
# Epoch 75/100
# 800/800 [==============================] - 1s 826us/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 76/100
# 800/800 [==============================] - 1s 881us/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 77/100
# 800/800 [==============================] - 1s 777us/step - loss: 0.0119 - val_loss: 0.0107
# Epoch 78/100
# 800/800 [==============================] - 1s 795us/step - loss: 0.0118 - val_loss: 0.0108
# Epoch 79/100
# 800/800 [==============================] - 1s 799us/step - loss: 0.0117 - val_loss: 0.0108
# Epoch 80/100
# 800/800 [==============================] - 1s 795us/step - loss: 0.0117 - val_loss: 0.0110
# Epoch 81/100
# 800/800 [==============================] - 1s 867us/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 82/100
# 800/800 [==============================] - 1s 798us/step - loss: 0.0118 - val_loss: 0.0107
# Epoch 83/100
# 800/800 [==============================] - 1s 819us/step - loss: 0.0118 - val_loss: 0.0107
# Epoch 84/100
# 800/800 [==============================] - 1s 837us/step - loss: 0.0117 - val_loss: 0.0109
# Epoch 85/100
# 800/800 [==============================] - 1s 819us/step - loss: 0.0117 - val_loss: 0.0109
# Epoch 86/100
# 800/800 [==============================] - 1s 896us/step - loss: 0.0118 - val_loss: 0.0107
# Epoch 87/100
# 800/800 [==============================] - 1s 954us/step - loss: 0.0117 - val_loss: 0.0107
# Epoch 88/100
# 800/800 [==============================] - 1s 847us/step - loss: 0.0117 - val_loss: 0.0108
# Epoch 89/100
# 800/800 [==============================] - 1s 853us/step - loss: 0.0118 - val_loss: 0.0107
# Epoch 90/100
# 800/800 [==============================] - 1s 817us/step - loss: 0.0120 - val_loss: 0.0111
# Epoch 91/100
# 800/800 [==============================] - 1s 842us/step - loss: 0.0119 - val_loss: 0.0114
# Epoch 92/100
# 800/800 [==============================] - 1s 783us/step - loss: 0.0120 - val_loss: 0.0116
# Epoch 93/100
# 800/800 [==============================] - 1s 850us/step - loss: 0.0123 - val_loss: 0.0114
# Epoch 94/100
# 800/800 [==============================] - 1s 893us/step - loss: 0.0121 - val_loss: 0.0111
# Epoch 95/100
# 800/800 [==============================] - 1s 788us/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 96/100
# 800/800 [==============================] - 1s 796us/step - loss: 0.0118 - val_loss: 0.0110
# Epoch 97/100
# 800/800 [==============================] - 1s 754us/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 98/100
# 800/800 [==============================] - 1s 814us/step - loss: 0.0120 - val_loss: 0.0115
# Epoch 99/100
# 800/800 [==============================] - 1s 793us/step - loss: 0.0120 - val_loss: 0.0111
# Epoch 100/100
# 800/800 [==============================] - 1s 833us/step - loss: 0.0119 - val_loss: 0.0112

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid'])

# %%
### predict for 10 steps
i=950
steps = 1
pred = np.empty(0)
data = X[i:i+1]
model = model_1Dconv_w_d

for j in range(0,steps):
  res = model.predict(data)[0].reshape(10)
  pred=np.append(pred,res)

plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)

### predict for 80 steps
i=950
steps = 8
pred = np.empty(0)
data = X[i:i+1]
model = model_1Dconv_w_d

for j in range(0,steps):
  res = model.predict(data)[0]
  res = res.reshape(10)
  pred=np.append(pred,res)

plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)

# %% [markdown]
# ### Simple RNN
#
# Now, let's use a RNN cell to see if we are able to learn the data generating process. We will use a hidden state size of 12.

# %%
model_simple_RNN = Sequential()

model_simple_RNN.add(SimpleRNN(12,return_sequences=True,input_shape=(128,1)))
model_simple_RNN.add((Dense(1)))
model_simple_RNN.add(Lambda(slice, arguments={'slice_length':look_ahead}))

model_simple_RNN.summary()
model_simple_RNN.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 128, 12)           168
# _________________________________________________________________
# dense_3 (Dense)              (None, 128, 1)            13
# _________________________________________________________________
# lambda_3 (Lambda)            (None, 10, 1)             0
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model_simple_RNN.fit(X[0:800], Y[0:800],
                    epochs=500,
                    batch_size=128,
                    validation_data=(X[800:1000],Y[800:1000]),
                    verbose=0)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid'])

# %%
### predict for 10 steps
i=950
steps = 1
pred = np.empty(0)
data = X[i:i+1]
model = model_simple_RNN

for j in range(0,steps):
  res = model.predict(data)[0].reshape(10)
  pred=np.append(pred,res)
    
plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)

### predict for 80 steps
i=950
steps = 8
pred = np.empty(0)
data = X[i:i+1]
model = model_simple_RNN

for j in range(0,steps):
  res = model.predict(data)[0].reshape(10)
  pred=np.append(pred,res)

plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)

# %% [markdown]
# ### LSTM Cell
#
# Let's use a more complex LSTM cell to and see if it works better than the RNN cell,  we again use a hidden state size of 12.

# %%
model_LSTM = Sequential()

model_LSTM.add(LSTM(12,return_sequences=True,input_shape=(128,1)))
model_LSTM.add((Dense(1)))
model_LSTM.add(Lambda(slice, arguments={'slice_length':look_ahead}))

model_LSTM.summary()
model_LSTM.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128, 12)           672
# _________________________________________________________________
# dense_4 (Dense)              (None, 128, 1)            13
# _________________________________________________________________
# lambda_4 (Lambda)            (None, 10, 1)             0
# =================================================================
# Total params: 685
# Trainable params: 685
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### To train the LSTM model takes some time, so we just load a trained model after 500 epochs

# %%
history = model_LSTM.fit(X[0:800], Y[0:800],
                    epochs=500,
                    batch_size=128,
                    validation_data=(X[800:1000],Y[800:1000]),
                    verbose=0)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
#
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid'])

# %%
#model_LSTM.save('../data/models/lstm_model_500_epochs.hdf5')

# %%
# we load the trained lstm model 
from keras.models import load_model
model_LSTM = load_model('../data/models/lstm_model_500_epochs.hdf5')
model_LSTM.summary()
# Out:
# -------------------------------------------------------------------------
# SystemError                             Traceback (most recent call last)
# <ipython-input-19-3db8505c9a71> in <module>
#       1 # we load the trained lstm model
#       2 from keras.models import load_model
# ----> 3 model_LSTM = load_model('../data/models/lstm_model_500_epochs.hdf5')
#       4 model_LSTM.summary()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\models.py in load_model(filepath, custom_objects, compile)
#     241             raise ValueError('No model found in config file.')
#     242         model_config = json.loads(model_config.decode('utf-8'))
# --> 243         model = model_from_config(model_config, custom_objects=custom_objects)
#     244
#     245         # set weights
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\models.py in model_from_config(config, custom_objects)
#     315                         'Maybe you meant to use '
#     316                         '`Sequential.from_config(config)`?')
# --> 317     return layer_module.deserialize(config, custom_objects=custom_objects)
#     318
#     319
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\__init__.py in deserialize(config, custom_objects)
#      53                                     module_objects=globs,
#      54                                     custom_objects=custom_objects,
# ---> 55                                     printable_module_name='layer')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     142                 return cls.from_config(config['config'],
#     143                                        custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 144                                                            list(custom_objects.items())))
#     145             with CustomObjectScope(custom_objects):
#     146                 return cls.from_config(config['config'])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\models.py in from_config(cls, config, custom_objects)
#    1371         for conf in config:
#    1372             layer = layer_module.deserialize(conf, custom_objects=custom_objects)
# -> 1373             model.add(layer)
#    1374         return model
#    1375
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\models.py in add(self, layer)
#     490                           output_shapes=[self.outputs[0]._keras_shape])
#     491         else:
# --> 492             output_tensor = layer(self.outputs[0])
#     493             if isinstance(output_tensor, list):
#     494                 raise TypeError('All layers in a Sequential model '
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\topology.py in __call__(self, inputs, **kwargs)
#     617
#     618             # Actually call the layer, collecting output(s), mask(s), and shape(s).
# --> 619             output = self.call(inputs, **kwargs)
#     620             output_mask = self.compute_mask(inputs, previous_mask)
#     621
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\core.py in call(self, inputs, mask)
#     661         if has_arg(self.function, 'mask'):
#     662             arguments['mask'] = mask
# --> 663         return self.function(inputs, **arguments)
#     664
#     665     def compute_mask(self, inputs, mask=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\core.py in slice(x, slice_length)
#
# SystemError: unknown opcode

# %%
model_LSTM.evaluate(X[0:800], Y[0:800])
# Out:
# 800/800 [==============================] - 0s 217us/step
# 0.011646481975913048

# %%
### predict for 10 steps
i=950
steps = 1
pred = np.empty(0)
data = X[i:i+1]
model = model_LSTM

for j in range(0,steps):
  res = model.predict(data)[0].reshape(10)
  pred=np.append(pred,res)

plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)

### predict for 80 steps
i=950
steps = 8
pred = np.empty(0)
data = X[i:i+1]
model = model_LSTM

for j in range(0,steps):
  res = model.predict(data)[0]
  res = res.reshape(10)
  data=(np.concatenate((data[0:1].reshape(128),res)))
  data=data[-128:]
  data=data.reshape((1,128,1))
  #data=data.reshape(1,128+(j)*10,1)[-128:]
  pred=np.append(pred,res)
data=X[i:i+1]  
plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)

# %% [markdown]
# ### Compare all models for very long predictions (800 timesteps)

# %%
i=950
steps = 80
pred = np.empty(0)
data = X[i:i+1]
model = model_1Dconv

for j in range(0,steps):
  res = model.predict(data)[0]
  res = res.reshape(10)
  data=(np.concatenate((data[0:1].reshape(128),res)))
  data=data[-128:]
  data=data.reshape((1,128,1))
  #data=data.reshape(1,128+(j)*10,1)[-128:]
  pred=np.append(pred,res)
data=X[i:i+1]  
plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)
plt.title("model_1Dconv")

i=950
steps = 80
pred = np.empty(0)
data = X[i:i+1]
model = model_1Dconv_w_d

for j in range(0,steps):
  res = model.predict(data)[0]
  res = res.reshape(10)
  data=(np.concatenate((data[0:1].reshape(128),res)))
  data=data[-128:]
  data=data.reshape((1,128,1))
  #data=data.reshape(1,128+(j)*10,1)[-128:]
  pred=np.append(pred,res)
data=X[i:i+1]  
plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)
plt.title("model_1Dconv_w_d")

i=950
steps = 80
pred = np.empty(0)
data = X[i:i+1]
model = model_simple_RNN

for j in range(0,steps):
  res = model.predict(data)[0]
  res = res.reshape(10)
  data=(np.concatenate((data[0:1].reshape(128),res)))
  data=data[-128:]
  data=data.reshape((1,128,1))
  #data=data.reshape(1,128+(j)*10,1)[-128:]
  pred=np.append(pred,res)
data=X[i:i+1]  
plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)
plt.title("model_simple_RNN")

i=950
steps = 80
pred = np.empty(0)
data = X[i:i+1]
model = model_LSTM

for j in range(0,steps):
  res = model.predict(data)[0]
  res = res.reshape(10)
  data=(np.concatenate((data[0:1].reshape(128),res)))
  data=data[-128:]
  data=data.reshape((1,128,1))
  #data=data.reshape(1,128+(j)*10,1)[-128:]
  pred=np.append(pred,res)
data=X[i:i+1]  
plt.figure(num=None, figsize=(13,5))
plt.plot(range(0,128),np.concatenate((data[0:1].reshape(128),pred))[0:128],color='blue')
plt.plot(range(128,128+steps*10),np.concatenate((data[0:1].reshape(128),pred))[128:128+steps*10],color='orange')
plt.axvline(x=128)
plt.title("model_LSTM")
# Out:
# Text(0.5, 1.0, 'model_LSTM')
